# %% [markdown]
# # Pandas

# %% [markdown]
# pandas is a powerful library generally used for
# 1. Data Cleaning
# 2. Data Transformation
# 3. Data Analysis
# 4. Machine Leaarning
# 5. Data Visualization

# %% [markdown]
# # Data Structures

# %% [markdown]
# There are two types of data structures in pandas
# 1. series
# 2. DataFrame

# %% [markdown]
# *Series*<br>
# A Pandas Series is a one-dimensional labeled array-like object that can hold data of any type.

# %% [markdown]
# *DataFrame*
# A DataFrame is like a table where the data is organized in rows and columns. It is a two-dimensional data structure like a two-dimensional array.

# %% [markdown]
# ![alt text](https://pandas.pydata.org/docs/_images/01_table_dataframe.svg)

# %% [markdown]
# Each column in a DataFrame is a Series

# %% [markdown]
# ![alt text](https://pandas.pydata.org/docs/_images/01_table_series.svg)
