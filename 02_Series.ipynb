# %% [markdown]
# # Series

# %% [markdown]
# # Creating a pandas
# there are two ways of creating series
# 1. using Python list
# 2. using Dictionary

# %%
import pandas as pd

# %% [markdown]
# Python List

# %%
# we will use Series function to create a pandas series
# make sure that the letter 'S' in Series is capital
pd = pd.Series([200,600,800,400,1000])
print(pd)
# Out:
# 0     200
# 1     600
# 2     800
# 3     400
# 4    1000
# dtype: int64
